# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = '2025-05-20_09-31-29_dataset-iris_nr-0.nnv'

df = pd.read_csv(file_path, sep='\t')

display(df)
# Out:
#       m0   m1   m2   m3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
corr_matrix = df.corr()
plt.figure(figsize=(7, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Matrice di Correlazione')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.suptitle("Pairplot delle variabili", y=1.02)
plt.show()
